# %% [markdown]
# # Sentiment Analysis of Silverlake Ramen Yelp Reviews
# ## From fillings, to text, to feelings!
# ***

# %% [markdown]
# ![](Ramenpng.png)

# %% [markdown]
# ***
# ## Description
#
#  Learning to scrape data has opened numerous doors for me. As a yelp user I am curious to see how my local ramen joint was doing. In this project I explore reviews and see how they translate into feelings using sentiment analysis.
#
#  _*This project is aimed at gaining insights from a analytics and educational standpoint and not a machine learning or predictive one._

# %% [markdown]
# ***
# ## TABLE OF CONTENTS
#
# * 1. [Setting Up Our Workstation and Loading in Libraries](#setup)
# * 2. [Data Import](#import)
# * 3. [Data Cleaning Using Tidy Principles](#clean)
#    * 3.1 [Cleaning data](#cleaning)
#    * 3.2 [Tokenization](#token)
#
# * 4. [Visualizations](#visual)
#     * 4.1 [Most Common Words: Wordcloud](#wordcloud)
#     * 4.2 [Most Common Words: Stacked Bar Chart](#barchart)
#     * 4.3 [Positive vs Negative Sentiment](#sentiment)
#     * 4.4 [Words Contributing to Each Positive/Negative Sentiment](#pssentiment)
#     * 4.5 [Categorizing Emotion](#emotion)
#     * 4.6 [Top Words Contributing to Each Respective Emotion](#topemotion)
#
# * 5. [Relationships of "n" Words](#nwords)
#     * 5.1 [Bigrams](#bigrams)
#     * 5.2 [Trigrams](#trigrams)
#
# * 6. [Visualizing Bigram Network](#network)
# * 7. [Conclusion/Insights/Endnotes](#end)
# ***

# %% [markdown]
# ### Questions in mind
#
# - **Besides "ramen", what are some other popular words?**
# - **What do the reviews say in terms of sentiment?**
# - **From these reviews, what does the positive vs negative sentiment look like?**
# - **Are there any combinations of words that stand out?**
# ***

# %% [markdown]
# ## 1. Setting Up Our Workstation and Load in Libraries, Yarimasho! <a id="setup"></a>
#
#    Before we begin lets load in relevant packages.

# %%
#suppresing warnings/messages for aesthetic purposes
suppressWarnings(suppressMessages(library(tidyverse)))
suppressWarnings(suppressMessages(library(tidytext)))
suppressWarnings(suppressMessages(library(textdata)))
suppressWarnings(suppressMessages(library(wordcloud)))

# %% [markdown]
# ## 2. Importing Our Data <a id="import"></a>
#
# Retrieving our data I've saved in Github (post web scraping).

# %%
# We read the dataset from github 
url <- "https://raw.githubusercontent.com/Rlegaspi562/Visualization-of-Sentiment-Analysis-of-Yelp-reviews/master/silverlakeramenyelp_dataset.csv"
yelp <- read_csv(url)

# Checking data
head(yelp)
glimpse(yelp)
# Out:
# Parsed with column specification:
# cols(
#   Reviews = col_character()
# )
#   Reviews
# 1 Your trust is our top concern, so businesses can't pay to alter or remove their reviews. Learn more.
# 2 Start your review of Silverlake Ramen.
# 3 I have been here at least 3 times to dine in person. Hospitality was always excellent but service was always slow since they are always so packed. Either arrive before the rush or order take out.
# 4 I ordered togo from this Silverlake Ramen at LBX yesterday, 5/5/2020. (Cant help but wonder if I was the only one in long beach eating ramen on cinco de mayo ) but anyways, I ordered then basic tonkotsu ramen and I was immediately impressed. The soup of the ramen was subtle and flavorful. Not at all salty or oily. The veggies tasted delightfully fresh and the noodles tasted as tho they were cut and boiled to perfection. The piece of chasu on top was melt in your delicious. On a separate occasion, I ordered the pork bun. It was massive and delicious as well!  Needless to say, I'll definitely be back.
# 5 Hi Bianca, I’m thrilled to see that you enjoyed your meal.  Take care!
# 6 I have been here twice in the last two weeks and it is yummy. Great service and awesome food and high quality. My family and I love Silverlake Ramen, double thumbs up.
# Observations: 315
# Variables: 1
# $ Reviews <chr> "Your trust is our top concern, so businesses can't pay to ...

# %% [markdown]
# ## 3. Data Cleaning Using Tidy Principles: Entering the Tidyverse<a id="clean"></a>
#
# In addition to reformatting our data to fit tidy principles, I will be
# __ommitting some rows in the dataset__ because after reading the yelp data and due to the webscraping process, I notice that some observations are actually business owner replies and are being counted as additional observations themselves. Fortunately, since the dataset is fairly manageable I can go through and __remove business owner replies, duplicates, and any other text that are not reviews__.

# %% [markdown]
# ### 3.1 Cleaning our data <a id="cleaning"></a>

# %%
# Removing business owner replies, yelp headings, and extra text.
yelp <- yelp[ -c(1, 2, 5, 7, 10, 23, 28, 29, 37, 40, 47, 56, 72, 79, 80, 93, 102, 103, 121, 126, 127, 128, 131, 151, 152, 162, 174, 175, 176, 193, 198, 199, 200, 219, 222, 223, 237, 246, 247, 268, 269, 283, 285, 292, 293, 304, 311) , ]

# %%
# Turning yelp data into a tibble format (data frame)
yelp_tibble <- as_tibble(yelp)

# Checking class to confirm
class(yelp_tibble)

# Removing duplicate rows 
yelp_tibble %>% distinct(Reviews, .keep_all = TRUE) %>%
head()

# Print
glimpse(yelp_tibble)
# Out:
# [1] "tbl_df"     "tbl"        "data.frame"
#   Reviews
# 1 I have been here at least 3 times to dine in person. Hospitality was always excellent but service was always slow since they are always so packed. Either arrive before the rush or order take out.
# 2 I ordered togo from this Silverlake Ramen at LBX yesterday, 5/5/2020. (Cant help but wonder if I was the only one in long beach eating ramen on cinco de mayo ) but anyways, I ordered then basic tonkotsu ramen and I was immediately impressed. The soup of the ramen was subtle and flavorful. Not at all salty or oily. The veggies tasted delightfully fresh and the noodles tasted as tho they were cut and boiled to perfection. The piece of chasu on top was melt in your delicious. On a separate occasion, I ordered the pork bun. It was massive and delicious as well!  Needless to say, I'll definitely be back.
# 3 I have been here twice in the last two weeks and it is yummy. Great service and awesome food and high quality. My family and I love Silverlake Ramen, double thumbs up.
# 4 Eh, it's ok if you're craving ramen but feeling too lazy to drive to Irvine or Torrance for proper ramen.Ordered The Blaze, spicy with pork. Wow, it came out in a comically huge bowl. Looks like a giant lake of broth with a little island in the middle made of noodles and spinach. The presentation just looks sparse and weird. Speaking of weird, the spinach was unexpected. I can't recall ever seeing spinach at any other ramen place. It just didn't add anything to the dish. Just a soggy green thing floating in your bowl. And there was one piece of sea weed clinging to the side of the bowl, far away from the noodle island. Again, strange sparse presentation. The noodles were average. The pork was super tender and was braised or blow torched to give it a slight crust. The broth was "ok" at first. But towards the end, I grabbed a spoon and slurped it up. I noticed a strange aftertaste. Not very pleasant. Also ordered the chicken karaage bowl. When it arrived at my table, it was covered in so many things. Again, not what you'd find at a traditional ramen place. I'll admit the actual chicken was great. Meat was tender and had the right deep fried crispiness. But the rock-n-roll mayo and terriyaki sauce ruined it. I highly suggest ordering it with sauces on the side. Also comes with a shredded pickled daikon as a garnish. It's really tangy. I don't hate it, but I could do without it.So now let's talk about the weird workflow. You walk in. You see one person at the register, and you see these giant tablets on the wall where you can self-order and pay with card. You ask yourself.. if you know what you want and you want to pay by card, do you cut ahead of everyone else in the line and punch in your order? Or do you wait in line and wait til you're face to face to the tablet? Well, I observed people doing both. I saw some confusing faces, as well as angry faces from people waiting in line. This is just a terrible idea, especially since not everyone was eager to use the giant tablet, even though they were paying by card at the register.Next, after you order and pay, you wait for someone to seat you. During peak hours, this is even more terrible idea. Because sometimes people eat slow and it takes a while for an empty table to come up. But since you've already paid, you're stuck. You can't just bounce to some other places to eat if the wait is too long.Prices are on par with other ramen places. If you think it's expensive, then you need to stick to the 25 cent Top Ramen you get at the store. I think karaage bowl is a great deal. You get a good amount of chicken and rice for the price. It's a meal in itself.Overall, not a bad place but not my first first choice either. I might go back and try their other items. But I wasn't impressed with their Blaze ramen and the weird workflow.
# 5 Very hip, very modern, very cool. I like it. The menu has a great mix of fresh, fried, and flavorful soup options. My guy had the more lighter broth ramen made with chicken, I had the ground chicken and egg bowl and we also got the cucumber crab salad and karaage (I think). I'm actually not a ramen shop girl because I feel like it's always a bit rich plus a lotta carbs but this restaurant does an excellent job of providing non pork options. With this place you order first and sit down, I love that there's an option for both indoor and outdoor seating. The servers come around to collect dishes as you finish, as well as to refill your water glass.Also great that you have a view of the kitchen while they're making your food. This restaurant is located on the other side of Georgia's, across from wahoo's and the opposite side of panini kabob grill.
# 6 *Heavy sigh* I had high hopes for Silver lake Ramen, hearing all the great reviews of their other location. I came in after the lunch rush about 2:00pm, and browsed the Yelp reviews--a bit of a mixed bag regarding the ramen, so I tried to keep it safe and order the chicken karaage bowl, and the pork bun. The bowl was pretty bad, something was "off" about the white rice, and the chicken tasted like fast food chicken doused in aioli. I think I took two bites and tossed it out. The pork bun wasn't any better--now I may be comparing it a regular bao but the pork was under-cooked and extremely fatty (not sure if this is norm), but the flavors of the ingredients in the bun did not go well together, at least imho. Lastly, I was in the restaurant for about 5/10 min, but the fishy smell is intense! They may need to install some more ventilation--I cant imagine eating there for lunch and going back to work smelling like fish :(I love ramen, so I will be back to try it the ramen.
# Observations: 268
# Variables: 1
# $ Reviews <chr> "I have been here at least 3 times to dine in person. Hospi...

# %% [markdown]
# ### 3.2 Tokenization <a id="token"></a>
#
# By performing tokenization, we essentially __transform our tibble dataset into a data frame of one word per row__. This will help ease the process of analyzing sentiment much easier by having our dataset in  this format.

# %%
# Tokenization (unnesting) in preparation for sentiment analysis (inner_join) to transform nontidy text data into tidy text data
tidy_yelp <- yelp_tibble %>%
  unnest_tokens(word, Reviews)

# Removing stopwords from our tidy_yelp dataset that are extremely common e.g. is, of, a, etc...
data("stop_words")
tidy_yelp <- tidy_yelp %>%
  anti_join(stop_words) 

# Checking
head(tidy_yelp)
# Out:
# Joining, by = "word"
#   word
# 1 3
# 2 times
# 3 dine
# 4 person
# 5 hospitality
# 6 excellent

# %% [markdown]
# ## 4. Output & Visualizations <a id="visual"></a>

# %% [markdown]
# ### 4.1  Most Common Words: Wordcloud <a id="wordcloud"></a>
#
# To start off, lets create an aesthetically pleasing wordcloud that illustrates the top 50 words in our dataset.

# %%
  #top 50 wordcloud
  tidy_yelp %>% 
    anti_join(stop_words) %>%
    count(word) %>%
    with(wordcloud(word,
                   freq = n,
                   scale=c(8,.3),
                   max.words = 50,
                   random.color = TRUE,
                   colors = c("brown3", "darkgoldenrod1", "tomato", "chartreuse4")))
# Out:
# Joining, by = "word"
# plot without title

# %% [markdown]
# ### 4.2 Most Common Words: Stacked Bar Chart  <a id="barchart"></a>
#
# Did some searching on the table and turns out the word update comes up 6 times, so out of 268 reviews, roughly 2% update?

# %%
# Output of most common words
tidy_yelp %>% 
  count(word, sort = TRUE)
 
# Visual
tidy_yelp %>% 
  count(word, sort = TRUE) %>%
  filter(n > 50) %>%
  mutate(word = reorder(word, n)) %>%
  ggplot(aes(x = word, y = n, fill = word)) +
  geom_col() +
  xlab(NULL) +
  ggtitle("Most Common Words") +
  theme(legend.position="none") +
  coord_flip()
# Out:
#      word           n
# 1    ramen          513
# 2    broth          159
# 3    pork           153
# 4    food           141
# 5    service        115
# 6    chicken        101
# 7    time            85
# 8    spicy           84
# 9    silverlake      81
# 10   noodles         69
# 11   wait            69
# 12   tonkotsu        64
# 13   blaze           63
# 14   table           59
# 15   bowl            58
# 16   delicious       52
# 17   location        50
# 18   line            49
# 19   classic         46
# 20   flavor          45
# 21   beach           44
# 22   bit             39
# 23   pretty          39
# 24   soup            39
# 25   soft            36
# 26   cashier         35
# 27   creamy          35
# 28   karaage         35
# 29   nice            35
# 30   super           35
# ...  ...            ...
# 2475 west           1
# 2476 wheat          1
# 2477 wholeheartedly 1
# 2478 wife's         1
# 2479 will.come      1
# 2480 wine           1
# 2481 wings          1
# 2482 wit            1
# 2483 wok            1
# 2484 wonderfully    1
# 2485 wonders        1
# 2486 wood           1
# 2487 woody          1
# 2488 worries        1
# 2489 worrying       1
# 2490 worthy         1
# 2491 woth           1
# 2492 wrath          1
# 2493 writing        1
# 2494 y'all.as       1
# 2495 ya'll          1
# 2496 yell           1
# 2497 yellow         1
# 2498 yelped         1
# 2499 yelpers        1
# 2500 yikes          1
# 2501 yo             1
# 2502 yolk           1
# 2503 yooooo         1
# 2504 zing           1
# plot without title

# %% [markdown]
# ### 4.3  Positive vs Negative Sentiment <a id="sentiment"></a>
#
# Here we introduce sentiment. But to do so, we first have to introduce **"lexicons"** to understand how these words are categorized by a "sentiment". There are different kinds of lexicons. __We can think of these lexicons as a kind of dictionary__. One of which is the "bing" lexicon that we will be using. When the "bing" lexicon is applied with our text set it will __indicate whether a word is positive or negative__.

# %%
# Implementing sentiment analysis
silverlake_bing_sentiment <- tidy_yelp %>%
  inner_join(get_sentiments("bing")) 


# Output
silverlake_bing_sentiment
# Out:
# Joining, by = "word"
#      word         sentiment
# 1    excellent    positive
# 2    slow         negative
# 3    impressed    positive
# 4    delightfully positive
# 5    fresh        positive
# 6    perfection   positive
# 7    top          positive
# 8    delicious    positive
# 9    delicious    positive
# 10   needless     negative
# 11   awesome      positive
# 12   love         positive
# 13   lazy         negative
# 14   proper       positive
# 15   wow          positive
# 16   weird        negative
# 17   weird        negative
# 18   unexpected   negative
# 19   weed         negative
# 20   strange      negative
# 21   super        positive
# 22   tender       positive
# 23   blow         negative
# 24   strange      negative
# 25   pleasant     positive
# 26   tender       positive
# 27   fried        negative
# 28   ruined       negative
# 29   hate         negative
# 30   weird        negative
# ...  ...          ...
# 1544 enjoyment    positive
# 1545 weird        negative
# 1546 delicious    positive
# 1547 popular      positive
# 1548 nice         positive
# 1549 bland        negative
# 1550 crowded      negative
# 1551 chaotic      negative
# 1552 super        positive
# 1553 amazing      positive
# 1554 generous     positive
# 1555 poor         negative
# 1556 horrible     negative
# 1557 horrible     negative
# 1558 incompetent  negative
# 1559 worth        positive
# 1560 clean        positive
# 1561 excellent    positive
# 1562 picky        negative
# 1563 delicious    positive
# 1564 favorite     positive
# 1565 incredible   positive
# 1566 gem          positive
# 1567 worth        positive
# 1568 fairly       positive
# 1569 crowded      negative
# 1570 friendly     positive
# 1571 helpful      positive
# 1572 clean        positive
# 1573 modern       positive

# %%
# Creating the visual
silverlake_bing_sentiment_bar <- silverlake_bing_sentiment %>% 
  count(sentiment) %>%

# Piping our previous output into a neat barchart to visualize
ggplot(aes(x = sentiment, y = n, fill = sentiment)) +
  geom_col(show.legend = FALSE) +
  xlab("Sentiment") +
  ylab("Frequency") +
  ggtitle("Frequency of Positive and Negative Sentiment") +
  geom_text(aes(label = n), position = position_dodge(width = 0.9), vjust = -0.25)

# Printing
silverlake_bing_sentiment_bar
# Out:
# plot without title

# %% [markdown]
# ### 4.4 Digging Deeper: What Words Contribute to Each Positive/Negative Sentiment? <a id="pssentiment"></a>

# %%
# In this line of code we add our custom stop words 
yelp_bing_counts <- tidy_yelp %>%
  inner_join(get_sentiments("bing")) %>%
  count(word, sentiment, sort = TRUE) %>%
  ungroup()

# Output of words with respective sentiment and frequency
yelp_bing_counts

# Visual
yelp_bing_counts %>%
  group_by(sentiment) %>%
  top_n(10) %>%
  ungroup() %>%
  mutate(word = reorder(word, n)) %>%
  ggplot(aes(x = word, y = n, fill = sentiment)) +
  geom_col(show.legend = FALSE) +
  facet_wrap(~sentiment, scales = "free") +
  labs(y = "Contribution to Sentiment",
       x = NULL) +
  ggtitle("Top 10 Words Contributing to Positive & Negative Sentiment") +
  coord_flip()
# Out:
# Joining, by = "word"
#     word           sentiment n
# 1   delicious      positive  52
# 2   classic        positive  46
# 3   pretty         positive  39
# 4   soft           positive  36
# 5   nice           positive  35
# 6   super          positive  35
# 7   love           positive  32
# 8   cold           negative  29
# 9   friendly       positive  29
# 10  perfect        positive  29
# 11  bad            negative  28
# 12  hot            positive  26
# 13  amazing        positive  24
# 14  tender         positive  24
# 15  rich           positive  22
# 16  disappointed   negative  20
# 17  fast           positive  20
# 18  recommend      positive  20
# 19  clean          positive  18
# 20  favorite       positive  17
# 21  loved          positive  17
# 22  enjoyed        positive  16
# 23  excited        positive  16
# 24  hard           negative  16
# 25  worth          positive  16
# 26  top            positive  14
# 27  weird          negative  14
# 28  attentive      positive  13
# 29  enjoy          positive  13
# 30  fried          negative  12
# ... ...            ...       ...
# 392 support        positive  1
# 393 suspect        negative  1
# 394 swift          positive  1
# 395 symptoms       negative  1
# 396 tease          negative  1
# 397 thoughtfully   positive  1
# 398 timely         positive  1
# 399 trendy         positive  1
# 400 trusted        positive  1
# 401 ugh            negative  1
# 402 unable         negative  1
# 403 unacceptable   negative  1
# 404 understandable positive  1
# 405 unexpected     negative  1
# 406 unlucky        negative  1
# 407 unnecessary    negative  1
# 408 unreal         positive  1
# 409 vague          negative  1
# 410 valuable       positive  1
# 411 wack           negative  1
# 412 warning        negative  1
# 413 waste          negative  1
# 414 weed           negative  1
# 415 wholeheartedly positive  1
# 416 wonderfully    positive  1
# 417 wonders        positive  1
# 418 worries        negative  1
# 419 worrying       negative  1
# 420 worthy         positive  1
# 421 wrath          negative  1
# Selecting by n
# plot without title

# %% [markdown]
# #### Removing Anamolies in Our Analysis
#
# Immediately after looking through the bar charts we see some __words being mistaken for the wrong sentiment__. These words: **fried, fatty, damn, and classic/blaze (item names on the menu)**, are words that __are neutral__ in a restaurant setting and can definitely be taken out of context in our visual so lets remove them. Lets also appreciate how the "bing" lexicon correctly identifies the word "cold" as negative and "hot" as positive, which is perfectly suitable in this case!

# %%
# We will create our own custom stop words
custom_stop_words1 <- bind_rows(tibble(word = c("fried", "damn", "hype", "classic", "blaze"), 
                                          lexicon = c("custom")), 
                               stop_words)

head(custom_stop_words1)
# Out:
#   word    lexicon
# 1 fried   custom
# 2 damn    custom
# 3 hype    custom
# 4 classic custom
# 5 blaze   custom
# 6 a       SMART

# %%
# Here are our new updated outputs and visuals!

# In this line of code we add our custom stop words
yelp_bing_counts <- tidy_yelp %>%
  inner_join(get_sentiments("bing")) %>%
  anti_join(custom_stop_words1) %>%
  count(word, sentiment, sort = TRUE) %>%
  ungroup()

# Print our new updated output
glimpse(yelp_bing_counts)

# Visual
  yelp_bing_counts %>%
  group_by(sentiment) %>%
  top_n(10) %>%
  ungroup() %>%
  mutate(word = reorder(word, n)) %>%
  ggplot(aes(x = word, y = n, fill = sentiment)) +
  geom_col(show.legend = FALSE) +
  facet_wrap(~sentiment, scales = "free") +
  labs(y =  "Contribution to Sentiment",
       x = NULL) +
  ggtitle("Top 10 Words Contributing to Positive & Negative Sentiment") +
  coord_flip()
# Out:
# Joining, by = "word"
# Joining, by = "word"
# Observations: 417
# Variables: 3
# $ word      <chr> "delicious", "pretty", "soft", "nice", "super", "love", "...
# $ sentiment <chr> "positive", "positive", "positive", "positive", "positive...
# $ n         <int> 52, 39, 36, 35, 35, 32, 29, 29, 29, 28, 26, 24, 24, 22, 2...
# Selecting by n
# plot without title

# %% [markdown]
# #### Great! Now these words make much more sense in their respective sentiments.

# %% [markdown]
# ### 4.5 Categorizing Emotion <a id="emotion"></a>
#
# In this visual, we will be displaying 6 emotions (__anticipation, joy, sadness, disgust, anger, and surprise__) using the **"nrc" lexicon**. Let us also filter out the trust/fear and positive/negative sentiments because it is also hard to truly gauge fear and trust with single text. Positive/negative sentiments will be filtered out because it has already been analyzed using the "bing" lexicon previously.

# %%
# Adjusting the "nrc" lexicon before implementation
 drop_sentiments <- c("fear", "trust", "positive", "negative")
 new_nrc <- get_sentiments("nrc") %>% 
filter(!sentiment %in% drop_sentiments)

# Print to check
head(new_nrc)

# Future me sees the data and needs to adjust
# Therefore we create our second custom stop words because these words either fit in the wrong emotion or are neutral
custom_stop_words2 <- bind_rows(tibble(word = c("food", "blaze", "yelp", "fatty", "damn","beach", "mouth", "deal", "pretty", "black", "tough", "chance", "mouth", "deal", "hope", "guess", "finally", "chicken", "serve", "feeling", "music", "leave", "bomb", "shopping", "perfect", "hot", "kick", "food"), 
                                          lexicon = c("custom")), 
                               stop_words)
# Print to check
head(custom_stop_words2)
# Out:
#   word        sentiment
# 1 abandon     sadness
# 2 abandoned   anger
# 3 abandoned   sadness
# 4 abandonment anger
# 5 abandonment sadness
# 6 abandonment surprise
#   word  lexicon
# 1 food  custom
# 2 blaze custom
# 3 yelp  custom
# 4 fatty custom
# 5 damn  custom
# 6 beach custom

# %%
# Implement sentiment analysis using our "new_nrc" lexicon 
 yelp_nrc <- tidy_yelp %>%
    inner_join(new_nrc) %>%
    anti_join(custom_stop_words2)
  
  
  yelp_nrc_plot <- yelp_nrc %>%
    group_by(sentiment) %>%
    summarise(word_count = n()) %>%
    ungroup() %>%
    mutate(sentiment = reorder(sentiment, word_count)) %>%
    
# Creating our visual
    ggplot(aes(sentiment, word_count, fill = -word_count)) +
    geom_col() +
    guides(fill = FALSE) + 
    labs(x = NULL, y = "Word Count") +
    scale_y_continuous(limits = c(0, 500)) + 
    ggtitle("Overall Emotions From Silverlake Reviews") +
    coord_flip()
  
  yelp_nrc_plot
# Out:
# Joining, by = "word"
# Joining, by = "word"
# plot without title

# %% [markdown]
# #### Looks like _"anticipation"_ and _"joy"_ is in the air!

# %% [markdown]
# ### 4.6 Top Words Contributing to Each Respective Emotion <a id="topemotion"></a>
#
# Again, digging a bit deeper, lets see what the top 3 words contributing to each respective emotion are.

# %%
# Implementing sentiment analysis
  yelp_nrc <- tidy_yelp %>%
    inner_join(new_nrc) %>%
    anti_join(custom_stop_words2)
    
  
# Which words contribute to the sentiment scores?
  yelp_nrc  %>%
    count(word, sentiment) %>%
    group_by(sentiment) %>%
    top_n(3) %>%
    ungroup() %>%
    mutate(word = reorder(word, n)) %>%
    ggplot(aes(x = word, y = n, fill = sentiment)) +
    geom_col(show.legend = FALSE) +
    facet_wrap(~ sentiment, scales = "free") +
    coord_flip()
# Out:
# Joining, by = "word"
# Joining, by = "word"
# Selecting by n
# plot without title

# %% [markdown]
# ## 5. Looking at the Relationships of Words <a id="nwords"></a>
#
# Looking at single words alone might not be entirely helpful. __Using pairs of words__ for analysis will help give us more context
# of reviews.
# Similar to tokenizations, we will be using something called "__tokens = ngrams__". This will allow us to categorize our data by "n" many words per row and __see how often word X is followed by word Y__.

# %% [markdown]
# ### 5.2 Lets look at pairs of words: Bigrams <a id="bigrams"></a>

# %%
#implementing tokenization at the bigram level
silverlake_bigrams <- yelp_tibble %>%
unnest_tokens(bigram, Reviews, token = "ngrams", n = 2)

# Printing bigrams
silverlake_bigrams %>%
  count(bigram, sort = TRUE)
# Out:
#       bigram                 n
# 1     it was                 127
# 2     and the                111
# 3     in the                  84
# 4     to the                  83
# 5     of the                  82
# 6     this place              78
# 7     the broth               72
# 8     the ramen               70
# 9     and i                   66
# 10    on the                  61
# 11    the pork                60
# 12    i was                   55
# 13    the blaze               54
# 14    was a                   54
# 15    silverlake ramen        51
# 16    ordered the             50
# 17    with the                50
# 18    ramen and               49
# 19    the food                46
# 20    broth was               44
# 21    is a                    44
# 22    but i                   43
# 23    for the                 43
# 24    but the                 42
# 25    long beach              42
# 26    to be                   42
# 27    a little                40
# 28    and it                  39
# 29    got the                 39
# 30    at the                  38
# ...   ...                    ...
# 16325 your option            1
# 16326 your product           1
# 16327 your protein           1
# 16328 your signature         1
# 16329 your so                1
# 16330 your staff's           1
# 16331 your stomach           1
# 16332 your taste             1
# 16333 your trust             1
# 16334 your tummy             1
# 16335 your wallet            1
# 16336 your water             1
# 16337 yourself a             1
# 16338 yourself establishment 1
# 16339 yourself if            1
# 16340 yourself it            1
# 16341 yum i                  1
# 16342 yum my                 1
# 16343 yum yummy              1
# 16344 yummy and              1
# 16345 yummy as               1
# 16346 yummy broth            1
# 16347 yummy but              1
# 16348 yummy great            1
# 16349 yummy had              1
# 16350 yummy i                1
# 16351 yummy place            1
# 16352 yummy ramen            1
# 16353 yummy yum              1
# 16354 zing that              1

# %% [markdown]
# As expected, we can see that most words that follow, or precede each other are __stop_words__ which do not provide much insight. Lets remove these.

# %%
# Creating new columns for word 1 and word 2
bigrams_separated <- silverlake_bigrams %>%
  separate(bigram, c("word1", "word2"), sep = " ")

# Filtering our stop_words
bigrams_filtered <- bigrams_separated %>%
  filter(!word1 %in% stop_words$word) %>%
  filter(!word2 %in% stop_words$word)

# New bigram counts:
bigram_counts <- bigrams_filtered %>% 
  count(word1, word2, sort = TRUE)

# Table output
bigram_counts
# Out:
#      word1      word2      n
# 1    silverlake ramen      51
# 2    pork       belly      25
# 3    tonkotsu   ramen      25
# 4    chicken    karaage    24
# 5    customer   service    23
# 6    spicy      tonkotsu   20
# 7    blaze      ramen      16
# 8    pork       bun        16
# 9    classic    tonkotsu   14
# 10   tonkatsu   ramen      12
# 11   chili      paste      11
# 12   original   location   11
# 13   shoyu      ramen      11
# 14   silver     lake       11
# 15   spicy      tuna       11
# 16   crispy     rice        9
# 17   ramen      broth       9
# 18   ramen      spot        9
# 19   veggie     ramen       9
# 20   bean       sprouts     8
# 21   black      garlic      8
# 22   ramen      hub         8
# 23   blaze      spicy       7
# 24   favorite   ramen       7
# 25   garlic     oil         7
# 26   highly     recommend   7
# 27   los        angeles     7
# 28   pork       broth       7
# 29   30         minutes     6
# 30   beach      exchange    6
# ...  ...        ...        ...
# 2235 word       spoken     1
# 2236 worker     told       1
# 2237 workers    drink      1
# 2238 workers    plain      1
# 2239 workers    stopped    1
# 2240 worst      ramen      1
# 2241 worst      service    1
# 2242 worth      waiting    1
# 2243 worthy     contenders 1
# 2244 woth       tofu       1
# 2245 would've   enjoyed    1
# 2246 wow        yummy      1
# 2247 write      home       1
# 2248 write      reviews    1
# 2249 wrong      job.if     1
# 2250 y'all      expect     1
# 2251 yell       send       1
# 2252 yellow     apron      1
# 2253 yelp       allowed    1
# 2254 yelp       listed     1
# 2255 yelp       listing    1
# 2256 yelp       reviews    1
# 2257 yelped     note       1
# 2258 yesterday  5          1
# 2259 yesterday  saturday   1
# 2260 yooooo     straight   1
# 2261 yum        yummy      1
# 2262 yummy      broth      1
# 2263 yummy      ramen      1
# 2264 yummy      yum        1

# %% [markdown]
# ### Visualizing Bigrams

# %%
# Visual of Bigrams  
bigrams_separated %>% 
  filter(!word1 %in% stop_words$word) %>%
  filter(!word2 %in% stop_words$word) %>% 
  unite(word,word1, word2, sep = " ") %>% 
  count(word, sort = TRUE)  %>%
  ungroup() %>%
  mutate(word = reorder(word, n)) %>%
  slice(1:15) %>%
  ggplot() + 
  geom_bar(aes(word, n), stat = "identity", fill = "#7FDCC0") +
  theme_minimal() +
  theme_bw() +
  coord_flip() +
  labs(title = "Top 15 Bigrams of Silverlake Ramen Reviews",
      x = "Word Pairs",
      y = "Frequency")
# Out:
# plot without title

# %% [markdown]
#  From this chart it is interesting that the only other word outside of the realm of food names and the location itself, is __customer service__. Must hold some importance aye?

# %% [markdown]
# ### 5.2 Lets not forget about 3-word pairs: Trigrams <a id="trigrams"></a>

# %%
# Tokenization at the trigram level
silverlake_trigrams <- yelp_tibble %>%
unnest_tokens(trigram, Reviews, token = "ngrams", n = 3)

# Printing trigram output
silverlake_trigrams %>%
  count(trigram, sort = TRUE)
# Out:
#       trigram                   n
# 1     the broth was             27
# 2     i ordered the             24
# 3     and it was                21
# 4     i got the                 21
# 5     in long beach             20
# 6     a lot of                  18
# 7     one of the                17
# 8     the long beach            14
# 9     the noodles were          14
# 10    the pork belly            14
# 11    the ramen was             14
# 12    it was a                  13
# 13    ordered the blaze         13
# 14    the blaze ramen           13
# 15    the broth is              13
# 16    the food was              13
# 17    the pork was              13
# 18    on the side               12
# 19    the best ramen            12
# 20    the service was           12
# 21    was a little              12
# 22    bowl of ramen             11
# 23    i had the                 11
# 24    if you want               11
# 25    in the area               11
# 26    the classic tonkotsu      11
# 27    this place is             11
# 28    was a bit                 11
# 29    you have to               11
# 30    be coming back            10
# ...   ...                       ...
# 25338 your so to                1
# 25339 your staff's mouth        1
# 25340 your stomach at           1
# 25341 your table before         1
# 25342 your table onto           1
# 25343 your taste buds           1
# 25344 your traditional karaage  1
# 25345 your traditional ramen    1
# 25346 your trust is             1
# 25347 your tummy will           1
# 25348 your wallet i             1
# 25349 your water glass.also     1
# 25350 yourself a favor          1
# 25351 yourself establishment so 1
# 25352 yourself if you           1
# 25353 yourself it was           1
# 25354 yum i love                1
# 25355 yum my wife               1
# 25356 yum yummy yum             1
# 25357 yummy and last            1
# 25358 yummy as well             1
# 25359 yummy broth just          1
# 25360 yummy but the             1
# 25361 yummy great service       1
# 25362 yummy had the             1
# 25363 yummy i ordered           1
# 25364 yummy place good          1
# 25365 yummy ramen the           1
# 25366 yummy yum i               1
# 25367 zing that maybe           1

# %%
# Creating new columns for word 1, word 2, and 3
trigrams_separated <- silverlake_trigrams %>%
  separate(trigram, c("word1", "word2", "word3"), sep = " ")

# Filtering our stop_words
trigrams_filtered <- trigrams_separated %>%
  filter(!word1 %in% stop_words$word) %>%
  filter(!word2 %in% stop_words$word) %>%
  filter(!word3 %in% stop_words$word)

# New trigram counts:
trigram_counts <- trigrams_filtered %>% 
  count(word1, word2, word3, sort = TRUE)

# Table Output
trigram_counts
# Out:
#     word1     word2      word3        n
# 1   spicy     tonkotsu   ramen        8
# 2   black     garlic     oil          7
# 3   classic   tonkotsu   ramen        6
# 4   silver    lake       ramen        6
# 5   chicken   karaage    bowl         5
# 6   crispy    chicken    karaage      5
# 7   blaze     spicy      tonkotsu     4
# 8   excellent customer   service      3
# 9   love      silverlake ramen        3
# 10  original  silverlake ramen        3
# 11  shin      sen        gumi         3
# 12  soft      boiled     egg          3
# 13  spicy     tonkatsu   ramen        3
# 14  15        20         minutes      2
# 15  added     bamboo     shoots       2
# 16  blaze     level      2            2
# 17  boneless  pork       rib          2
# 18  classic   tonkatsu   ramen        2
# 19  cold      california days         2
# 20  corn      seaweed    jalapeño     2
# 21  green     onion      corn         2
# 22  lakewood  hwy        19           2
# 23  means     pork       duh          2
# 24  monday    9          30           2
# 25  moved     pretty     quick        2
# 26  onion     corn       seaweed      2
# 27  pork      belly      steak        2
# 28  pork      bone       broth        2
# 29  pork      rib        stewed       2
# 30  ramen     recently   expanded     2
# ... ...       ...        ...          ...
# 805 visit     excellent  customer     1
# 806 wait      1          2hr          1
# 807 wait      minus      1            1
# 808 wait      sadly      disappointed 1
# 809 waited    30         mins         1
# 810 waited    30         minutes      1
# 811 waited    40         min          1
# 812 waited    40         minutes      1
# 813 waited    food       arrives      1
# 814 waiters   too.come   check        1
# 815 waitress  4          times        1
# 816 wannabe   food       critic       1
# 817 warm      cozy       blanket      1
# 818 warm      wood       stainless    1
# 819 warmed    stiff      pork         1
# 820 wasting   valuable   real         1
# 821 water     tasted     pretty       1
# 822 weird     kiosk      system       1
# 823 white     chicken    breast       1
# 824 white     menu       boards       1
# 825 wife      finally    received     1
# 826 wonders   i’m        glad         1
# 827 wood      stainless  dark         1
# 828 workers   drink      water        1
# 829 worst     ramen      cuisine      1
# 830 worthy    contenders silverlake   1
# 831 yell      send       noodz        1
# 832 yesterday 5          5            1
# 833 yesterday saturday   10           1
# 834 yum       yummy      yum          1

# %%
# Visual of Trigrams
trigrams_separated %>% 
  filter(!word1 %in% stop_words$word) %>%
  filter(!word2 %in% stop_words$word) %>%
  filter(!word3 %in% stop_words$word) %>%
  unite(word,word1, word2, word3, sep = " ") %>% 
  count(word, sort = TRUE)  %>%
  ungroup() %>%
  mutate(word = reorder(word, n)) %>%
  slice(1:15) %>%
  ggplot() + 
  geom_bar(aes(word, n), stat = "identity", fill = "#7FDCC0") +
  theme_minimal() +
  theme_bw() +
  coord_flip() +
  labs(title = "Top 15 Trigrams of Silverlake Ramen Reviews",
      x = "Word Pairs",
      y = "Frequency")
# Out:
# plot without title

# %% [markdown]
# ## _*Unfortunately, due to incompatibilities with R kernel and packages being loaded into Jupyter Notebook this next section is uploaded as an image file._ :(
#
# ## 6. VIsualizing a Bigram Network <a id="network"></a>

# %% [markdown]
# ![](bigramnetworkcode&output.PNG)

# %% [markdown]
# ![](bigramnetworkvisual.PNG)
# ![](bigramnodenetworkvisual.PNG)

# %% [markdown]
# ### The arrows indicate which words are more likely to precede other words. The indication becomes stronger the darker the arrow.
#  ***

# %% [markdown]
# ![](Ramenpng22.png)

# %% [markdown]
# # 7. Insights <a id="end"></a>
#
# - Aside from the word "ramen", the next **most mentioned word is "broth" and closely following "pork"**, these elements of the dish **hold great weight in a good or bad bowl.**
# - Most common words: After food, **customer service and wait/time are the next most popular categories**
# - **Food temperature (cold) contributes to most of the negative sentiment**, whereas the opposite is not true at all. Hot food is not mentioned to the same degree as cold food is. **Food texture (hard/soft) is the next most popular category that contributes to positive/negative sentiment**
# - **Anticipation (time/wait)** closely followed by **joy** are the **emotions mainly displayed** on these reviews**
# - **Again**, for most common bigrams, **customer service is the next most mentioned category**
#
# ## Conclusion
#
#    The amount of information that can be gathered text alone is endless. I can only imagine how great the effects text analysis can have on other topics/industries.
#    Thanks to computational power and online resources this personal project has allowed me to apply my skills in extracting information from text data. Overall, even though much of the findings were to be expected, **it is reassuring to see how the data is in line with my previous inclination as a ramen connaisseur**. The data shows why **broth and pork are truly some of the driving factors for a tasty bowl of ramen!**

# %% [markdown]
# ## What I've Learned:
#
# - Data cleaning might still occur during the exploratory data analysis phase
# - Sometimes insights might not be something groundbreaking but can help with confirming or disproving previous biases
# - Colors and images make a huge difference in grabbing attention and overall presentability
# - Although I wasn't able to incorporate it here due to file size limitations I learned how to use plotly and data tables to create interactive tables
# - Overcoming technical frustration and finding workarounds when using Rkernel inside jupyter notebook and other incompatibilities with github repositories
#
#
# ## Looking Forward:
#
# - Scrape to obtain all reviews
# - Exploring/visualizing this data on tableau
# - Using r shiny/plotly to create shareable and interactive deliverables
# - Better control with personal machine to debug inconsistencices
#
# ### Notable Mentions and Resources:
#
#  **So grateful for these useful reads and articles which were great references in guiding me throughout. Special thanks to all of these and many others!**
#
# 1. _Text Mining with R_
# __A Tidy Approach__
# Julia Silge and David Robinson
# 2020-03-07
#
# 2. _Tidy Sentiment Analysis in R_
# __Debbie Liske__
